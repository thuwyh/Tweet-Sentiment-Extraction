# %%
import pandas as pd
import numpy as np

# %matplotlib inline

# %%
train = pd.read_csv('../input/tweet-sentiment-extraction/tweet_dataset.csv')

# %%
train.dropna(subset=['selected_text'], inplace=True)
train.drop_duplicates(subset=['text'], inplace=True)

# %%
train.head()
# Out:
#        textID   sentiment         author  \
# 1  1956967666     sadness      wannamama
# 2  1956967696     sadness      coolfunky
# 3  1956967789  enthusiasm    czareaquino
# 4  1956968416     neutral      xkilljoyx
# 5  1956968477       worry  xxxPEACHESxxx
#
#                                                 text  \
# 1  Layin n bed with a headache  ughhhh...waitin o...
# 2                Funeral ceremony...gloomy friday...
# 3               wants to hang out with friends SOON!
# 4   We want to trade with someone who has Houston...
# 5  Re-pinging : why didn`t you go to prom? BC my ...
#
#                                             old_text      aux_id  \
# 1  Layin n bed with a headache  ughhhh...waitin o...  c811396dc2
# 2                Funeral ceremony...gloomy friday...  9063631ab1
# 3               wants to hang out with friends SOON!  2a815f151d
# 4  @dannycastillo We want to trade with someone w...  82565a56d3
# ...

# %%
train.shape
# Out:
# (27480, 8)

# %%
train['whole'] = (train['selected_text'].str.len()/train['text'].str.len()>0.95)

# %%
train[train['whole']&(train['new_sentiment']!='neutral')]
# Out:
#            textID   sentiment         author  \
# 3      1956967789  enthusiasm    czareaquino
# 8      1956969035     sadness    nic0lepaula
# 11     1956969531       worry   dudeitsmanda
# 29     1956973690       worry  catchtheapple
# 90     1956988145     neutral      padfootly
# ...           ...         ...            ...
# 39843  1753886145      relief  paulverhoeven
# 39922  1753903114   happiness      SocialPro
# 39940  1753903552   happiness  aymanelhattab
# 39954  1753903927    surprise      yandrasap
# 39981  1753904919   happiness   DominiqueGoh
#
#                                                 text  \
# 3               wants to hang out with friends SOON!
# 8                       Charlene my love. I miss you
# 11                           Choked on her retainers
# 29     I HATE CANCER. I HATE IT I HATE IT I HATE IT.
# 90                       what`s going on sweetheart?
# ...                                              ...
# ...

# %%
print(train.loc[39843, 'text'])
# Out:
#  Smile. Everything worked out.

# %%
train[~train['whole']&(train['new_sentiment']!='neutral')]
# Out:
#            textID  sentiment           author  \
# 1      1956967666    sadness        wannamama
# 2      1956967696    sadness        coolfunky
# 5      1956968477      worry    xxxPEACHESxxx
# 12     1956970047    sadness         Danied32
# 13     1956970424    sadness          Samm_xo
# ...           ...        ...              ...
# 39987  1753918809  happiness          njohari
# 39988  1753918818  happiness  RachellSmithles
# 39992  1753918881    neutral      _Alectrona_
# 39996  1753919001       love         drapeaux
# 39997  1753919005       love         JenniRox
#
#                                                     text  \
# 1      Layin n bed with a headache  ughhhh...waitin o...
# 2                    Funeral ceremony...gloomy friday...
# 5      Re-pinging : why didn`t you go to prom? BC my ...
# 12     Ugh! I have to beat this stupid song to get to...
# 13      if u watch the hills in london u will realise...
# ...                                                  ...
# ...
